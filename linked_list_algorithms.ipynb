# %%
# Insertion at Beginning
"""
Algorithm
1. START
2. Create a node to store the data
3. Check if the list is empty
4. If the list is empty, add the data to the node and assign the head pointer to it.
5 If the list is not empty, add the data to a node and link to the current head. Assign the head to the newly added node.
6. END
"""

# Make a class called Node that will contain the data in the linked list
class Node:
   # Privately initialize the function with instance/s and blank data parameter in the linked list
   def __init__(self, data=None):
      # Create an instance of data
      self.data = data
      # There is initially no next node
      self.next = None
# Make a class called SLL that will contain the head for the linked list and the listprint function
class SLL:
   # Privately initialize the function with a blank head to start the linked list with instance/s
   def __init__(self):
      # There is initially no head
      self.head = None

# Create a function that prints the linked list with instance/s
   def listprint(self):
      # Create a variable to represent the head of the linked list
      printval = self.head
      print("Linked List: ")
      # If there is data to print, the head will not be None and creates a while loop to go through the linked list
      while printval is not None:
         # Prints the current node in the linked list
         print (printval.data)
         # Goes to the next node in the linked list
         printval = printval.next
    # Create a function to create new nodes with instance/s and a parameter called newdata
   def AddAtBeginning(self,newdata):
      # Create nodes with a variable called called NewNode by calling the Node class and the newdata parameter
      NewNode = Node(newdata)

      # Update the new nodes next value to existing nodes
      NewNode.next = self.head
      self.head = NewNode

# Makes a new variable called l1 that calls the SLL class to start the linked list (do not need to call Node class since it is a part of the SLL class already)
l1 = SLL()
# Head of the linked list
l1.head = Node("731")
# Data in first node
e2 = Node("672")
# Data in second node
e3 = Node("63")

# Next in first node
l1.head.next = e2

# Next in second node
e2.next = e3

# Creates a new node
l1.AddAtBeginning("122")

# Print the linked list with listprint() function I defined (must use listprint() function, cannot use print())
l1.listprint()
# Out:
# Linked List:
# 122
# 731
# 672
# 63

# %%
# Insertion at Ending
"""
Algorithm
1. START
2. Create a new node and assign the data
3. Find the last node
4. Point the last node to new node
5. END
"""

# Make a class called Node that will contain the data in the linked list
class Node:
   # Privately initialize the function with instance/s and blank data parameter in the linked list
   def __init__(self, data=None):
      # Create an instance of data
      self.data = data
      # There is initially no next node
      self.next = None
# Make a class called LL that will contain the head for the linked list and the listprint function
class LL:
   # Create a variable to represent the head of the linked list with instance/s
   def __init__(self):
      # There is initially no head
      self.head = None
   # Create a function that prints the linked list with instance/s
   def listprint(self):
      # Create a variable to represent the head of the linked list
      printval = self.head
      print("Linked List: ")
      # If there is data to print, the head will not be None and creates a while loop to go through the linked list
      while printval is not None:
         # Prints the current node in the linked list
         print (printval.data)
         # Goes to the next node in the linked list
         printval = printval.next

# Makes a new variable called l1 that calls the LL class to start the linked list
l1 = LL()
# Head of the linked list
l1.head = Node("23")
# Data in the first node
l2 = Node("12")
# Data in the second node
l3 = Node("7")
# Data in the third node
l4 = Node("14")
# Data in the fourth node
l5 = Node("61")

# Linking the head to the first node
l1.head.next = l2

# Linking the first node to the second node
l2.next = l3
# Linking the second node to the third node
l3.next = l4
# Linkng the third node to the fourth node
l4.next = l5

# Printing the list with the listprint function
l1.listprint()
# Out:
# Linked List:
# 23
# 12
# 7
# 14
# 61

# %%
# Insertion at a Given Position
"""Algorithm
1. START
2. Create a new node and assign data to it
3. Iterate until the node at position is found
4. Point first to new first node
5. END
"""

#Make a class called Node that will contain the data in the linked list
class Node:
   # Privately initialize the function with instance/s and a blank data parameter in the linked list
   def __init__(self, data=None):
      # Create an instance of data
      self.data = data
      # There is initially no next node
      self.next = None

# Make a class called SLL that will contain the head for the linked list and the listprint function
class SLL:
   # Privately initialize the function with a blank head to start the linked list with instance/s
   def __init__(self): 
      # There is initially no head
      self.head = None

   # Create a function that prints the linked list with instance/s
   def listprint(self):
      # Create a variable to represent the head of the linked list
      printval = self.head
      print("Linked List: ")
      # If there is data to print, the head will not be None and creates a while loop to go through the linked list
      while printval is not None:
         # Prints the current node in the linked list
         print (printval.data)
         # Goes to the next node in the linked list
         printval = printval.next

   # Function to insert a node with instance/s, parameter called nodeatpos, and parameter called newdata
   def InsertAtPos(self,nodeatpos,newdata):
      # If there is no node in a position
      if nodeatpos is None:
         # Prints a string
         print("The mentioned node is absent")
         # Returns
         return
      # Variable called newnode calls the Node function and newdata parameter
      NewNode = Node(newdata)
      # WHAT?? PLEASE EXPLAIN THIS PART
      NewNode.next = nodeatpos.next
      nodeatpos.next = NewNode

# Creates a list using the SLL class
l1 = SLL()
# Head for the linked list
l1.head = Node("731")
# Data for the first node
e2 = Node("672")
# Data for the second node
e3 = Node("63")

# Go from the head to the first node
l1.head.next = e2
# Go from the first node to the second node
e2.next = e3

# Inserts a node after the head
l1.InsertAtPos(l1.head.next, "122")
#Prints the edited list
l1.listprint()
# Out:
# Linked List:
# 731
# 672
# 122
# 63

# %%
# Reverse Operation
"""
Algorithm
Step by step process to reverse a linked list is as follows −

1 START
2. We use three pointers to perform the reversing: prev, next, head.
3. Point the current node to head and assign its next value to the prev node.
4. Iteratively repeat the step 3 for all the nodes in the list.
5. Assign head to the prev node.
"""
#Make a class called Node that will contain the data in the linked list
class Node:
   # Privately initialize the function with instance/s and blank data parameter in the linked list
   def __init__(self, data=None):
      # Create an instance of data
      self.data = data
      # There is initially no next node
      self.next = None

# Make a class called SLL that will contain the head for the linked list and the listprint function
class SLL:
   # Privately initialize the function with a blank head to start the linked list with instance/s
   def __init__(self):
      # There is initially no head
      self.head = None

   # Create a function that prints the linked list with instance/s
   def listprint(self):
      # Create a variable to represent the head of the linked list
      printval = self.head
      print("Linked List: ")
      # If there is data to print, the head will not be None and creates a while loop to go through the linked list
      while printval is not None:
         # Prints the current node in the linked list
         print (printval.data)
         # Goes to the next node in the linked list
         printval = printval.next
   # Creat a function that reverses the linked list order with instance/s
   def reverse(self):
      # Prev variable is none to later add
      prev = None
      # Curr variable starts at the head
      curr = self.head
      # Creates a while loop
      while(curr is not None):
         # Define variable called next (Confusing)
         next = curr.next
         curr.next = prev
         prev = curr
         curr = next
      self.head = prev

# Creates a list using the SLL class
l1 = SLL()
# Head for the linked list
l1.head = Node("731")
# Data for the first node
e2 = Node("672")
# Data for the second node
e3 = Node("63")

# Go from the head to the first node
l1.head.next = e2
# Go from the first node to the second node
e2.next = e3

# Print the linked list
l1.listprint()
# Reverse the linked list
l1.reverse()
# Print the reversed linked list
print("After reversing: ")
l1.listprint()
# Out:
# Linked List:
# 731
# 672
# 63
# After reversing:
# Linked List:
# 63
# 672
# 731

# %%
# Search Operation
"""
Algorithm
1 START
2 If the list is not empty, iteratively check if the list contains the key
3 If the key element is not present in the list, unsuccessful search
4 END
"""

#Make a class called Node that will contain the data in the linked list
class Node:
   # Privately initialize the function with instance/s and an empty data parameter in the linked list
   def __init__(self, data=None):
      # Create an instance of data
      self.data = data
      # There is initially no next node
      self.next = None

# Make a class called SLL that will contain the head for the linked list and the listprint function
class SLL:
   # Privately initialize the function with a blank head to start the linked list with instance/s
   def __init__(self):
      # There is initially no head
      self.head = None
   # Create a search function starting at 0 which is the head with instance/s and a parameter x
   def search(self, x):
      count = 0
      
      # Initialize current to head
      current = self.head

      # Loop till current variable not equal to None
      while current != None:
         # If the current variable is equals x, prints data found
         if current.data == x:
            print("data found")
            # Has to add one each time since 0 is the head
            count = count + 1
         # Keeps looping until the data is found
         current = current.next
      # The head is not data
      if count == 0:
         print("Data Not found")

# Creates a list using the SLL class
l1 = SLL()
# Head for the linked list
l1.head = Node("731")
# Data for the first node
e2 = Node("672")
# Data for the second node
e3 = Node("63")

# Go from the head to the first node
l1.head.next = e2
# Go from the first node to the second node
e2.next = e3

# Use search function
l1.search("63")
# Out:
# data found

# %%
# Traversal Operation (Nothing added)
"""
Algorithm
1. START
2. While the list is not empty and did not reach the end of the list, print the data in each node
3. END
"""
#Make a class called Node that will contain the data in the linked list
class Node:
   # Privately initialize the function with a blank data parameter in the linked list with instance/s
   def __init__(self, data=None):
      # Create an instance of data
      self.data = data
      # There is initially no next node
      self.next = None

# Make a class called LL that will contain the head for the linked list and the listprint function
class LL:
   # Create a variable to represent the head of the linked list with instance/s
   def __init__(self):
      # There is initially no head
      self.head = None
   # Create a function that prints the linked list with instance/s
   def listprint(self):
      # Create a variable to represent the head of the linked list
      printval = self.head
      print("Linked List: ")
      # If there is data to print, the head will not be None and creates a while loop to go through the linked list
      while printval is not None:
         # Prints the current node in the linked list
         print (printval.data)
         # Goes to the next node in the linked list
         printval = printval.next

# Creates a list using the LL class
l1 = LL()
# Head for the linked list
l1.head = Node("731")
# Data for the first node
e2 = Node("672")
# Data for the second node
e3 = Node("63")

# Go from the head to the first node
l1.head.next = e2
# Go from the first node to the second node
e2.next = e3

# Print the linked list with listprint() function I defined (must use listprint() function, cannot use print())
l1.listprint()
# Out:
# Linked List:
# 731
# 672
# 63

# %%
# Linked List
class Node():
    def __init__(self, data=None):
        self.data = data
        self.next = None

class LL():
    def __init__(self):
        self.head = None
        self.tail = None

    def listprint(self):
        printval = self.head
        print("The values are:")
        while printval is not None:
            print(printval.data)
            printval = printval.next

    def add(self, node):
         # h         t
         # O -> O -> O
        if self.tail == None or self.head == None:
            self.head = node
            self.tail = node
            return
        self.tail.next = node
        self.tail = node
        return
    
    def remove(self, node):
        curr = node
        prev = None
        if curr == self.head:
            self.head = self.head.next
        elif curr == self.tail:
            
    while curr is not None:
        prev.next = curr.next
# Out:
#   Cell In[4], line 37
#     while curr is not None:
#     ^
# IndentationError: expected an indented block
